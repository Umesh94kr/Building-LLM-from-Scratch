# %% [markdown]
# #### **Saving and Loading Model in PyTorch**
#
# -> torch.save(model.state_dict(), 'model.pth')
#              - dictionary mapping each layer to its params | file name
#
# -> model.load_state_dict(torch.load(model.pth))
#
# #### **Optimizer should also be saved**
# During Training only let say you have to pause training then optimizer may loose previous gradients
